# %% [markdown]
# <a href="https://colab.research.google.com/github/THARIK-ASAN2003/THARIK-ASAN2003/blob/main/XG_BOOST_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_recall_curve
from sklearn.preprocessing import RobustScaler, LabelEncoder
import xgboost as xgb
import warnings
import json
warnings.filterwarnings('ignore')

# %%
# Set random seed for reproducibility
np.random.seed(42)

# %%
# Load the data
train = pd.read_csv('/content/Railofy_training_data_for_model.csv')
test = pd.read_csv("/content/Railofy_testing_data_for_model.csv")

# %%
# Null value check function
def check_null_values(df, dataset_name):
    print(f"\nNull Value Check for {dataset_name}:")
    null_counts = df.isna().sum()
    null_percentages = (df.isna().sum() / len(df)) * 100
    null_info = pd.DataFrame({
        'Null Count': null_counts,
        'Null Percentage': null_percentages
    })
    null_info = null_info[null_info['Null Count'] > 0]
    if len(null_info) > 0:
        print(null_info)
    else:
        print("No null values found!")
    return null_info

# %%
# Handle null values function
def handle_null_values(df):
    df_clean = df.copy()
    numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
    for col in numeric_columns:
        if df[col].isna().sum() > 0:
            df_clean[col] = df_clean[col].fillna(df_clean[col].median())

    categorical_columns = df.select_dtypes(include=['object']).columns
    for col in categorical_columns:
        if df[col].isna().sum() > 0:
            df_clean[col] = df_clean[col].fillna(df_clean[col].mode()[0])
    return df_clean

# %%
# Check and handle null values
train_nulls = check_null_values(train, "Training Data")
test_nulls = check_null_values(test, "Test Data")

if len(train_nulls) > 0:
    train_clean = handle_null_values(train)
else:
    train_clean = train

if len(test_nulls) > 0:
    test_clean = handle_null_values(test)
else:
    test_clean = test
# Out:
# Null Value Check for Training Data:
# No null values found!
#
# Null Value Check for Test Data:
# No null values found!

# %%
# Verify null values handled
print("\nVerifying null values after handling:")
check_null_values(train_clean, "Cleaned Training Data")
check_null_values(test_clean, "Cleaned Test Data")
# Out:
# Verifying null values after handling:
#
# Null Value Check for Cleaned Training Data:
# No null values found!
#
# Null Value Check for Cleaned Test Data:
# No null values found!
# Empty DataFrame
# Columns: [Null Count, Null Percentage]
# Index: []

# %%
# Data preprocessing function
def preprocess_data(train_df, test_df, target_column='target'):
    if target_column in train_df.columns:
        y = train_df[target_column].copy()
        X = train_df.drop(columns=[target_column])
    else:
        y = None
        X = train_df.copy()

    X_test = test_df.copy()
    numeric_columns = X.select_dtypes(include=['int64', 'float64']).columns
    categorical_columns = X.select_dtypes(include=['object']).columns
    rb_scaler = RobustScaler()
    label_encoders = {}

    if len(numeric_columns) > 0:
        X_numeric = pd.DataFrame(rb_scaler.fit_transform(X[numeric_columns]),
                                columns=numeric_columns,
                                index=X.index)
        X_test_numeric = pd.DataFrame(rb_scaler.transform(X_test[numeric_columns]),
                                     columns=numeric_columns,
                                     index=X_test.index)
    else:
        X_numeric = pd.DataFrame(index=X.index)
        X_test_numeric = pd.DataFrame(index=X_test.index)

    X_categorical = pd.DataFrame(index=X.index)
    X_test_categorical = pd.DataFrame(index=X_test.index)

    for col in categorical_columns:
        le = LabelEncoder()
        X_categorical[col] = le.fit_transform(X[col])
        X_test_categorical[col] = le.transform(X_test[col])
        label_encoders[col] = le

    X_processed = pd.concat([X_numeric, X_categorical], axis=1)
    X_test_processed = pd.concat([X_test_numeric, X_test_categorical], axis=1)

    return X_processed, X_test_processed, y, label_encoders

# %%
# Apply preprocessing
X_processed, X_test_processed, y, label_encoders = preprocess_data(train_clean, test_clean)

# %%
# Split the data
X_train, X_valid, y_train, y_valid = train_test_split(
    X_processed, y,
    test_size=0.2,
    random_state=2021
)

print("Dataset shapes after preprocessing:")
print(f"X_train: {X_train.shape}")
print(f"X_valid: {X_valid.shape}")
print(f"X_test: {X_test_processed.shape}")
# Out:
# Dataset shapes after preprocessing:
# X_train: (29420, 24)
# X_valid: (7355, 24)
# X_test: (3847, 24)

# %%
# Train XGBoost model
xgb_model = xgb.XGBClassifier(
    random_state=2022,
    n_estimators=10000,
    learning_rate=0.01,
    max_depth=6,
    n_jobs=-1,
    verbosity=1,
    use_label_encoder=False,
    eval_metric='logloss'
)

# %%
# Train the model
eval_set = [(X_valid, y_valid)]
xgb_model.fit(
    X_train,
    y_train,
    eval_set=eval_set,
    verbose=True
)
# Out:
# Streaming output truncated to the last 5000 lines.
# [5000]	validation_0-logloss:0.22465
# [5001]	validation_0-logloss:0.22463
# [5002]	validation_0-logloss:0.22459
# [5003]	validation_0-logloss:0.22457
# [5004]	validation_0-logloss:0.22455
# [5005]	validation_0-logloss:0.22453
# [5006]	validation_0-logloss:0.22452
# [5007]	validation_0-logloss:0.22448
# [5008]	validation_0-logloss:0.22447
# [5009]	validation_0-logloss:0.22445
# [5010]	validation_0-logloss:0.22445
# [5011]	validation_0-logloss:0.22441
# [5012]	validation_0-logloss:0.22441
# [5013]	validation_0-logloss:0.22440
# [5014]	validation_0-logloss:0.22437
# [5015]	validation_0-logloss:0.22436
# [5016]	validation_0-logloss:0.22437
# [5017]	validation_0-logloss:0.22435
# [5018]	validation_0-logloss:0.22434
# [5019]	validation_0-logloss:0.22432
# [5020]	validation_0-logloss:0.22432
# [5021]	validation_0-logloss:0.22431
# [5022]	validation_0-logloss:0.22428
# [5023]	validation_0-logloss:0.22429
# [5024]	validation_0-logloss:0.22425
# [5025]	validation_0-logloss:0.22425
# [5026]	validation_0-logloss:0.22423
# [5027]	validation_0-logloss:0.22422
# [5028]	validation_0-logloss:0.22419
# [5029]	validation_0-logloss:0.22417
# [5030]	validation_0-logloss:0.22416
# [5031]	validation_0-logloss:0.22416
# [5032]	validation_0-logloss:0.22415
# [5033]	validation_0-logloss:0.22415
# [5034]	validation_0-logloss:0.22412
# [5035]	validation_0-logloss:0.22412
# [5036]	validation_0-logloss:0.22412
# [5037]	validation_0-logloss:0.22409
# [5038]	validation_0-logloss:0.22408
# [5039]	validation_0-logloss:0.22406
# [5040]	validation_0-logloss:0.22405
# [5041]	validation_0-logloss:0.22402
# [5042]	validation_0-logloss:0.22400
# [5043]	validation_0-logloss:0.22397
# [5044]	validation_0-logloss:0.22395
# [5045]	validation_0-logloss:0.22395
# [5046]	validation_0-logloss:0.22391
# [5047]	validation_0-logloss:0.22390
# [5048]	validation_0-logloss:0.22389
# [5049]	validation_0-logloss:0.22386
# [5050]	validation_0-logloss:0.22386
# [5051]	validation_0-logloss:0.22384
# [5052]	validation_0-logloss:0.22381
# [5053]	validation_0-logloss:0.22377
# [5054]	validation_0-logloss:0.22376
# [5055]	validation_0-logloss:0.22373
# [5056]	validation_0-logloss:0.22372
# [5057]	validation_0-logloss:0.22371
# [5058]	validation_0-logloss:0.22371
# [5059]	validation_0-logloss:0.22371
# [5060]	validation_0-logloss:0.22368
# [5061]	validation_0-logloss:0.22366
# [5062]	validation_0-logloss:0.22362
# [5063]	validation_0-logloss:0.22362
# [5064]	validation_0-logloss:0.22361
# [5065]	validation_0-logloss:0.22359
# [5066]	validation_0-logloss:0.22357
# [5067]	validation_0-logloss:0.22356
# [5068]	validation_0-logloss:0.22356
# [5069]	validation_0-logloss:0.22351
# [5070]	validation_0-logloss:0.22349
# [5071]	validation_0-logloss:0.22349
# [5072]	validation_0-logloss:0.22348
# [5073]	validation_0-logloss:0.22344
# [5074]	validation_0-logloss:0.22344
# [5075]	validation_0-logloss:0.22343
# [5076]	validation_0-logloss:0.22342
# [5077]	validation_0-logloss:0.22341
# [5078]	validation_0-logloss:0.22339
# [5079]	validation_0-logloss:0.22339
# [5080]	validation_0-logloss:0.22338
# [5081]	validation_0-logloss:0.22336
# [5082]	validation_0-logloss:0.22332
# [5083]	validation_0-logloss:0.22330
# [5084]	validation_0-logloss:0.22328
# [5085]	validation_0-logloss:0.22327
# [5086]	validation_0-logloss:0.22325
# [5087]	validation_0-logloss:0.22324
# [5088]	validation_0-logloss:0.22320
# [5089]	validation_0-logloss:0.22319
# [5090]	validation_0-logloss:0.22318
# [5091]	validation_0-logloss:0.22315
# [5092]	validation_0-logloss:0.22315
# [5093]	validation_0-logloss:0.22315
# [5094]	validation_0-logloss:0.22314
# [5095]	validation_0-logloss:0.22314
# [5096]	validation_0-logloss:0.22314
# [5097]	validation_0-logloss:0.22311
# [5098]	validation_0-logloss:0.22308
# [5099]	validation_0-logloss:0.22306
# [5100]	validation_0-logloss:0.22303
# [5101]	validation_0-logloss:0.22302
# [5102]	validation_0-logloss:0.22301
# [5103]	validation_0-logloss:0.22298
# [5104]	validation_0-logloss:0.22297
# [5105]	validation_0-logloss:0.22291
# [5106]	validation_0-logloss:0.22290
# [5107]	validation_0-logloss:0.22290
# [5108]	validation_0-logloss:0.22286
# [5109]	validation_0-logloss:0.22285
# [5110]	validation_0-logloss:0.22284
# [5111]	validation_0-logloss:0.22282
# [5112]	validation_0-logloss:0.22281
# [5113]	validation_0-logloss:0.22280
# [5114]	validation_0-logloss:0.22279
# [5115]	validation_0-logloss:0.22278
# [5116]	validation_0-logloss:0.22277
# [5117]	validation_0-logloss:0.22277
# [5118]	validation_0-logloss:0.22276
# [5119]	validation_0-logloss:0.22274
# [5120]	validation_0-logloss:0.22273
# [5121]	validation_0-logloss:0.22271
# [5122]	validation_0-logloss:0.22271
# [5123]	validation_0-logloss:0.22270
# [5124]	validation_0-logloss:0.22269
# [5125]	validation_0-logloss:0.22267
# [5204]	validation_0-logloss:0.22157
# [5205]	validation_0-logloss:0.22156
# [5206]	validation_0-logloss:0.22153
# [5207]	validation_0-logloss:0.22151
# [5208]	validation_0-logloss:0.22150
# [5209]	validation_0-logloss:0.22149
# [5210]	validation_0-logloss:0.22146
# [5211]	validation_0-logloss:0.22142
# [5212]	validation_0-logloss:0.22141
# [5213]	validation_0-logloss:0.22139
# [5214]	validation_0-logloss:0.22138
# [5215]	validation_0-logloss:0.22137
# [5216]	validation_0-logloss:0.22133
# [5217]	validation_0-logloss:0.22131
# [5218]	validation_0-logloss:0.22130
# [5219]	validation_0-logloss:0.22128
# [5220]	validation_0-logloss:0.22126
# [5221]	validation_0-logloss:0.22126
# [5222]	validation_0-logloss:0.22125
# [5223]	validation_0-logloss:0.22122
# [5224]	validation_0-logloss:0.22122
# [5225]	validation_0-logloss:0.22121
# [5226]	validation_0-logloss:0.22120
# [5227]	validation_0-logloss:0.22117
# [5228]	validation_0-logloss:0.22116
# [5229]	validation_0-logloss:0.22113
# [5230]	validation_0-logloss:0.22112
# [5231]	validation_0-logloss:0.22110
# [5232]	validation_0-logloss:0.22109
# [5233]	validation_0-logloss:0.22108
# [5234]	validation_0-logloss:0.22108
# [5235]	validation_0-logloss:0.22106
# [5236]	validation_0-logloss:0.22106
# [5237]	validation_0-logloss:0.22103
# [5238]	validation_0-logloss:0.22099
# [5239]	validation_0-logloss:0.22098
# [5240]	validation_0-logloss:0.22095
# [5241]	validation_0-logloss:0.22095
# [5242]	validation_0-logloss:0.22093
# [5243]	validation_0-logloss:0.22093
# [5244]	validation_0-logloss:0.22091
# [5245]	validation_0-logloss:0.22089
# [5246]	validation_0-logloss:0.22087
# [5247]	validation_0-logloss:0.22086
# [5248]	validation_0-logloss:0.22085
# [5249]	validation_0-logloss:0.22083
# [5250]	validation_0-logloss:0.22082
# [5251]	validation_0-logloss:0.22080
# [5252]	validation_0-logloss:0.22079
# [5253]	validation_0-logloss:0.22076
# [5254]	validation_0-logloss:0.22076
# [5255]	validation_0-logloss:0.22072
# [5256]	validation_0-logloss:0.22067
# [5257]	validation_0-logloss:0.22063
# [5258]	validation_0-logloss:0.22063
# [5259]	validation_0-logloss:0.22061
# [5260]	validation_0-logloss:0.22059
# [5261]	validation_0-logloss:0.22059
# [5262]	validation_0-logloss:0.22058
# [5263]	validation_0-logloss:0.22055
# [5264]	validation_0-logloss:0.22054
# [5265]	validation_0-logloss:0.22053
# [5266]	validation_0-logloss:0.22051
# [5267]	validation_0-logloss:0.22049
# [5268]	validation_0-logloss:0.22047
# [5269]	validation_0-logloss:0.22045
# [5270]	validation_0-logloss:0.22044
# [5271]	validation_0-logloss:0.22043
# [5272]	validation_0-logloss:0.22042
# [5273]	validation_0-logloss:0.22038
# [5274]	validation_0-logloss:0.22037
# [5275]	validation_0-logloss:0.22036
# [5276]	validation_0-logloss:0.22036
# [5277]	validation_0-logloss:0.22033
# [5278]	validation_0-logloss:0.22031
# [5279]	validation_0-logloss:0.22028
# [5280]	validation_0-logloss:0.22027
# [5281]	validation_0-logloss:0.22023
# [6060]	validation_0-logloss:0.21024
# [6061]	validation_0-logloss:0.21024
# [6062]	validation_0-logloss:0.21022
# [6063]	validation_0-logloss:0.21021
# [6064]	validation_0-logloss:0.21020
# [6065]	validation_0-logloss:0.21019
# [6066]	validation_0-logloss:0.21018
# [6067]	validation_0-logloss:0.21017
# [6068]	validation_0-logloss:0.21017
# [6069]	validation_0-logloss:0.21016
# [6070]	validation_0-logloss:0.21015
# [6071]	validation_0-logloss:0.21015
# [6072]	validation_0-logloss:0.21012
# [6073]	validation_0-logloss:0.21010
# [6074]	validation_0-logloss:0.21010
# [6075]	validation_0-logloss:0.21009
# [6076]	validation_0-logloss:0.21010
# [6077]	validation_0-logloss:0.21008
# [6078]	validation_0-logloss:0.21007
# [6079]	validation_0-logloss:0.21007
# [6080]	validation_0-logloss:0.21004
# [6081]	validation_0-logloss:0.21003
# [6082]	validation_0-logloss:0.21003
# [6083]	validation_0-logloss:0.21002
# [6084]	validation_0-logloss:0.21002
# [6085]	validation_0-logloss:0.21001
# [6086]	validation_0-logloss:0.20999
# [6087]	validation_0-logloss:0.20999
# [6088]	validation_0-logloss:0.20996
# [6089]	validation_0-logloss:0.20996
# [6090]	validation_0-logloss:0.20993
# [6091]	validation_0-logloss:0.20993
# [6092]	validation_0-logloss:0.20992
# [6093]	validation_0-logloss:0.20991
# [6094]	validation_0-logloss:0.20990
# [6095]	validation_0-logloss:0.20990
# [6096]	validation_0-logloss:0.20990
# [6097]	validation_0-logloss:0.20988
# [6098]	validation_0-logloss:0.20987
# [6099]	validation_0-logloss:0.20987
# [6100]	validation_0-logloss:0.20985
# [6101]	validation_0-logloss:0.20985
# [6102]	validation_0-logloss:0.20985
# [6103]	validation_0-logloss:0.20984
# [6104]	validation_0-logloss:0.20982
# [6105]	validation_0-logloss:0.20980
# [6106]	validation_0-logloss:0.20979
# [6107]	validation_0-logloss:0.20977
# [6108]	validation_0-logloss:0.20976
# [6109]	validation_0-logloss:0.20975
# [6110]	validation_0-logloss:0.20972
# [6111]	validation_0-logloss:0.20971
# [6112]	validation_0-logloss:0.20970
# [6113]	validation_0-logloss:0.20969
# [6114]	validation_0-logloss:0.20968
# [6115]	validation_0-logloss:0.20967
# [6116]	validation_0-logloss:0.20965
# [6117]	validation_0-logloss:0.20965
# [6118]	validation_0-logloss:0.20965
# [6119]	validation_0-logloss:0.20964
# [6120]	validation_0-logloss:0.20963
# [6121]	validation_0-logloss:0.20962
# [6122]	validation_0-logloss:0.20960
# [6123]	validation_0-logloss:0.20959
# [6124]	validation_0-logloss:0.20957
# [6125]	validation_0-logloss:0.20956
# [6126]	validation_0-logloss:0.20955
# [6127]	validation_0-logloss:0.20954
# [6128]	validation_0-logloss:0.20953
# [6129]	validation_0-logloss:0.20952
# [6130]	validation_0-logloss:0.20950
# [6131]	validation_0-logloss:0.20949
# [6132]	validation_0-logloss:0.20948
# [6133]	validation_0-logloss:0.20948
# [6134]	validation_0-logloss:0.20945
# [6135]	validation_0-logloss:0.20944
# [6136]	validation_0-logloss:0.20942
# [6137]	validation_0-logloss:0.20940
# [6138]	validation_0-logloss:0.20940
# [6139]	validation_0-logloss:0.20939
# [6140]	validation_0-logloss:0.20937
# [6141]	validation_0-logloss:0.20936
# [6142]	validation_0-logloss:0.20935
# [6143]	validation_0-logloss:0.20932
# [6144]	validation_0-logloss:0.20931
# [6145]	validation_0-logloss:0.20930
# [6146]	validation_0-logloss:0.20929
# [6147]	validation_0-logloss:0.20927
# [6148]	validation_0-logloss:0.20926
# [6149]	validation_0-logloss:0.20925
# [6150]	validation_0-logloss:0.20925
# [6151]	validation_0-logloss:0.20924
# [6152]	validation_0-logloss:0.20923
# [6153]	validation_0-logloss:0.20922
# [6154]	validation_0-logloss:0.20921
# [6155]	validation_0-logloss:0.20919
# [6156]	validation_0-logloss:0.20920
# [6157]	validation_0-logloss:0.20919
# [6158]	validation_0-logloss:0.20919
# [6159]	validation_0-logloss:0.20918
# [6160]	validation_0-logloss:0.20917
# [6161]	validation_0-logloss:0.20917
# [6162]	validation_0-logloss:0.20915
# [6163]	validation_0-logloss:0.20915
# [6164]	validation_0-logloss:0.20913
# [6165]	validation_0-logloss:0.20911
# [6166]	validation_0-logloss:0.20910
# [6167]	validation_0-logloss:0.20909
# [6168]	validation_0-logloss:0.20908
# [6169]	validation_0-logloss:0.20908
# [6170]	validation_0-logloss:0.20907
# [6171]	validation_0-logloss:0.20906
# [6172]	validation_0-logloss:0.20906
# [6173]	validation_0-logloss:0.20905
# [6174]	validation_0-logloss:0.20904
# [6175]	validation_0-logloss:0.20901
# [6176]	validation_0-logloss:0.20898
# [6177]	validation_0-logloss:0.20897
# [6178]	validation_0-logloss:0.20897
# [6179]	validation_0-logloss:0.20897
# [6180]	validation_0-logloss:0.20897
# [6181]	validation_0-logloss:0.20896
# [6182]	validation_0-logloss:0.20894
# [6183]	validation_0-logloss:0.20893
# [6184]	validation_0-logloss:0.20891
# [6185]	validation_0-logloss:0.20889
# [6186]	validation_0-logloss:0.20889
# [6187]	validation_0-logloss:0.20886
# [6188]	validation_0-logloss:0.20885
# [6189]	validation_0-logloss:0.20885
# [6190]	validation_0-logloss:0.20883
# [6191]	validation_0-logloss:0.20883
# [6192]	validation_0-logloss:0.20882
# [6193]	validation_0-logloss:0.20879
# [6194]	validation_0-logloss:0.20879
# [6195]	validation_0-logloss:0.20878
# [6196]	validation_0-logloss:0.20876
# [6197]	validation_0-logloss:0.20874
# [6198]	validation_0-logloss:0.20873
# [6199]	validation_0-logloss:0.20872
# [6200]	validation_0-logloss:0.20871
# [6201]	validation_0-logloss:0.20867
# [6202]	validation_0-logloss:0.20866
# [6203]	validation_0-logloss:0.20863
# [6204]	validation_0-logloss:0.20862
# [6205]	validation_0-logloss:0.20862
# [6206]	validation_0-logloss:0.20859
# [6207]	validation_0-logloss:0.20856
# [6208]	validation_0-logloss:0.20855
# [6209]	validation_0-logloss:0.20852
# [6210]	validation_0-logloss:0.20849
# [6211]	validation_0-logloss:0.20846
# [6212]	validation_0-logloss:0.20845
# [6213]	validation_0-logloss:0.20842
# [6214]	validation_0-logloss:0.20841
# [6215]	validation_0-logloss:0.20839
# [6216]	validation_0-logloss:0.20839
# [6217]	validation_0-logloss:0.20836
# [6218]	validation_0-logloss:0.20834
# [6219]	validation_0-logloss:0.20831
# [6220]	validation_0-logloss:0.20830
# [6221]	validation_0-logloss:0.20829
# [6222]	validation_0-logloss:0.20828
# [6223]	validation_0-logloss:0.20826
# [6224]	validation_0-logloss:0.20825
# [6225]	validation_0-logloss:0.20824
# [6226]	validation_0-logloss:0.20824
# [6227]	validation_0-logloss:0.20822
# [6228]	validation_0-logloss:0.20820
# [6229]	validation_0-logloss:0.20817
# [6230]	validation_0-logloss:0.20816
# [6231]	validation_0-logloss:0.20815
# [6232]	validation_0-logloss:0.20813
# [6233]	validation_0-logloss:0.20813
# [6234]	validation_0-logloss:0.20812
# [6235]	validation_0-logloss:0.20811
# [6236]	validation_0-logloss:0.20810
# [6237]	validation_0-logloss:0.20809
# [6238]	validation_0-logloss:0.20807
# [6239]	validation_0-logloss:0.20805
# [6240]	validation_0-logloss:0.20804
# [6241]	validation_0-logloss:0.20803
# [6242]	validation_0-logloss:0.20802
# [6243]	validation_0-logloss:0.20800
# [6244]	validation_0-logloss:0.20798
# [6245]	validation_0-logloss:0.20798
# [6246]	validation_0-logloss:0.20798
# [6247]	validation_0-logloss:0.20796
# [6248]	validation_0-logloss:0.20793
# [6249]	validation_0-logloss:0.20792
# [6250]	validation_0-logloss:0.20791
# [6251]	validation_0-logloss:0.20790
# [6252]	validation_0-logloss:0.20788
# [6253]	validation_0-logloss:0.20788
# [6254]	validation_0-logloss:0.20786
# [6255]	validation_0-logloss:0.20785
# [6256]	validation_0-logloss:0.20784
# [6257]	validation_0-logloss:0.20783
# [6258]	validation_0-logloss:0.20782
# [6259]	validation_0-logloss:0.20780
# [6260]	validation_0-logloss:0.20779
# [6261]	validation_0-logloss:0.20777
# [6262]	validation_0-logloss:0.20775
# [6263]	validation_0-logloss:0.20775
# [6264]	validation_0-logloss:0.20773
# [6265]	validation_0-logloss:0.20773
# [6266]	validation_0-logloss:0.20773
# [6267]	validation_0-logloss:0.20770
# [6268]	validation_0-logloss:0.20769
# [6269]	validation_0-logloss:0.20767
# [6270]	validation_0-logloss:0.20766
# [6271]	validation_0-logloss:0.20765
# [6272]	validation_0-logloss:0.20764
# [6273]	validation_0-logloss:0.20763
# [6274]	validation_0-logloss:0.20761
# [6275]	validation_0-logloss:0.20759
# [6276]	validation_0-logloss:0.20758
# [6277]	validation_0-logloss:0.20756
# [6278]	validation_0-logloss:0.20756
# [6279]	validation_0-logloss:0.20755
# [6280]	validation_0-logloss:0.20752
# [6281]	validation_0-logloss:0.20750
# [6282]	validation_0-logloss:0.20750
# [6283]	validation_0-logloss:0.20749
# [6284]	validation_0-logloss:0.20746
# [6285]	validation_0-logloss:0.20745
# [6286]	validation_0-logloss:0.20744
# [6287]	validation_0-logloss:0.20743
# [6288]	validation_0-logloss:0.20741
# [6289]	validation_0-logloss:0.20741
# [6290]	validation_0-logloss:0.20740
# [6291]	validation_0-logloss:0.20739
# [6292]	validation_0-logloss:0.20738
# [6293]	validation_0-logloss:0.20738
# [6294]	validation_0-logloss:0.20736
# [6295]	validation_0-logloss:0.20735
# [6296]	validation_0-logloss:0.20735
# [6297]	validation_0-logloss:0.20732
# [6298]	validation_0-logloss:0.20731
# [6299]	validation_0-logloss:0.20729
# [6300]	validation_0-logloss:0.20728
# [6301]	validation_0-logloss:0.20727
# [6302]	validation_0-logloss:0.20724
# [6303]	validation_0-logloss:0.20723
# [6304]	validation_0-logloss:0.20722
# [6305]	validation_0-logloss:0.20721
# [6306]	validation_0-logloss:0.20719
# [6307]	validation_0-logloss:0.20716
# [6308]	validation_0-logloss:0.20715
# [6309]	validation_0-logloss:0.20713
# [6310]	validation_0-logloss:0.20712
# [6311]	validation_0-logloss:0.20712
# [6312]	validation_0-logloss:0.20712
# [6313]	validation_0-logloss:0.20709
# [6314]	validation_0-logloss:0.20706
# [6315]	validation_0-logloss:0.20704
# [6316]	validation_0-logloss:0.20703
# [6317]	validation_0-logloss:0.20702
# [6318]	validation_0-logloss:0.20701
# [6319]	validation_0-logloss:0.20701
# [6320]	validation_0-logloss:0.20699
# [6321]	validation_0-logloss:0.20696
# [6322]	validation_0-logloss:0.20696
# [6323]	validation_0-logloss:0.20693
# [6324]	validation_0-logloss:0.20691
# [6325]	validation_0-logloss:0.20689
# [6326]	validation_0-logloss:0.20689
# [6327]	validation_0-logloss:0.20688
# [6328]	validation_0-logloss:0.20687
# [6329]	validation_0-logloss:0.20687
# [6330]	validation_0-logloss:0.20687
# ...
# [9578]	validation_0-logloss:0.18518
# [9579]	validation_0-logloss:0.18519
# [9580]	validation_0-logloss:0.18519
# [9581]	validation_0-logloss:0.18518
# [9582]	validation_0-logloss:0.18517
# [9583]	validation_0-logloss:0.18516
# [9584]	validation_0-logloss:0.18516
# [9585]	validation_0-logloss:0.18516
# [9586]	validation_0-logloss:0.18517
# [9587]	validation_0-logloss:0.18516
# [9588]	validation_0-logloss:0.18515
# [9589]	validation_0-logloss:0.18514
# [9590]	validation_0-logloss:0.18515
# [9591]	validation_0-logloss:0.18515
# [9592]	validation_0-logloss:0.18515
# [9593]	validation_0-logloss:0.18515
# [9594]	validation_0-logloss:0.18514
# [9595]	validation_0-logloss:0.18512
# [9596]	validation_0-logloss:0.18512
# [9597]	validation_0-logloss:0.18511
# [9598]	validation_0-logloss:0.18512
# [9599]	validation_0-logloss:0.18511
# [9600]	validation_0-logloss:0.18512
# [9601]	validation_0-logloss:0.18511
# [9602]	validation_0-logloss:0.18511
# [9603]	validation_0-logloss:0.18512
# [9604]	validation_0-logloss:0.18512
# [9605]	validation_0-logloss:0.18511
# [9606]	validation_0-logloss:0.18511
# [9607]	validation_0-logloss:0.18510
# [9608]	validation_0-logloss:0.18509
# [9609]	validation_0-logloss:0.18510
# [9610]	validation_0-logloss:0.18510
# [9611]	validation_0-logloss:0.18510
# [9612]	validation_0-logloss:0.18509
# [9613]	validation_0-logloss:0.18509
# [9614]	validation_0-logloss:0.18507
# [9615]	validation_0-logloss:0.18507
# [9616]	validation_0-logloss:0.18507
# [9617]	validation_0-logloss:0.18507
# [9618]	validation_0-logloss:0.18507
# [9619]	validation_0-logloss:0.18507
# [9620]	validation_0-logloss:0.18507
# [9621]	validation_0-logloss:0.18507
# [9622]	validation_0-logloss:0.18507
# [9623]	validation_0-logloss:0.18507
# [9624]	validation_0-logloss:0.18506
# [9625]	validation_0-logloss:0.18506
# [9626]	validation_0-logloss:0.18506
# [9627]	validation_0-logloss:0.18506
# [9628]	validation_0-logloss:0.18505
# [9629]	validation_0-logloss:0.18504
# [9630]	validation_0-logloss:0.18505
# [9631]	validation_0-logloss:0.18505
# [9632]	validation_0-logloss:0.18505
# [9633]	validation_0-logloss:0.18503
# [9634]	validation_0-logloss:0.18502
# [9635]	validation_0-logloss:0.18502
# [9636]	validation_0-logloss:0.18500
# [9637]	validation_0-logloss:0.18499
# [9638]	validation_0-logloss:0.18496
# [9639]	validation_0-logloss:0.18497
# [9640]	validation_0-logloss:0.18497
# [9641]	validation_0-logloss:0.18497
# [9642]	validation_0-logloss:0.18496
# [9643]	validation_0-logloss:0.18496
# [9644]	validation_0-logloss:0.18496
# [9645]	validation_0-logloss:0.18496
# [9646]	validation_0-logloss:0.18496
# [9647]	validation_0-logloss:0.18495
# [9648]	validation_0-logloss:0.18493
# [9649]	validation_0-logloss:0.18492
# [9650]	validation_0-logloss:0.18491
# [9651]	validation_0-logloss:0.18490
# [9652]	validation_0-logloss:0.18490
# [9653]	validation_0-logloss:0.18488
# [9654]	validation_0-logloss:0.18488
# [9655]	validation_0-logloss:0.18486
# [9656]	validation_0-logloss:0.18485
# [9657]	validation_0-logloss:0.18484
# [9658]	validation_0-logloss:0.18483
# [9659]	validation_0-logloss:0.18483
# [9660]	validation_0-logloss:0.18482
# [9661]	validation_0-logloss:0.18481
# [9662]	validation_0-logloss:0.18481
# [9663]	validation_0-logloss:0.18479
# [9664]	validation_0-logloss:0.18478
# [9665]	validation_0-logloss:0.18478
# [9666]	validation_0-logloss:0.18478
# [9667]	validation_0-logloss:0.18476
# [9668]	validation_0-logloss:0.18477
# [9669]	validation_0-logloss:0.18477
# [9670]	validation_0-logloss:0.18476
# [9671]	validation_0-logloss:0.18476
# [9672]	validation_0-logloss:0.18476
# [9673]	validation_0-logloss:0.18477
# [9674]	validation_0-logloss:0.18476
# [9675]	validation_0-logloss:0.18476
# [9676]	validation_0-logloss:0.18476
# [9677]	validation_0-logloss:0.18476
# [9678]	validation_0-logloss:0.18474
# [9679]	validation_0-logloss:0.18474
# [9680]	validation_0-logloss:0.18474
# [9681]	validation_0-logloss:0.18473
# [9682]	validation_0-logloss:0.18473
# [9683]	validation_0-logloss:0.18473
# [9684]	validation_0-logloss:0.18473
# [9685]	validation_0-logloss:0.18472
# [9686]	validation_0-logloss:0.18472
# [9687]	validation_0-logloss:0.18473
# [9688]	validation_0-logloss:0.18473
# [9689]	validation_0-logloss:0.18472
# [9690]	validation_0-logloss:0.18472
# [9691]	validation_0-logloss:0.18470
# [9692]	validation_0-logloss:0.18471
# [9693]	validation_0-logloss:0.18471
# [9694]	validation_0-logloss:0.18471
# [9695]	validation_0-logloss:0.18470
# [9696]	validation_0-logloss:0.18469
# [9697]	validation_0-logloss:0.18469
# [9698]	validation_0-logloss:0.18468
# [9699]	validation_0-logloss:0.18469
# [9700]	validation_0-logloss:0.18468
# [9701]	validation_0-logloss:0.18468
# [9702]	validation_0-logloss:0.18465
# [9703]	validation_0-logloss:0.18466
# [9704]	validation_0-logloss:0.18464
# [9705]	validation_0-logloss:0.18465
# [9706]	validation_0-logloss:0.18464
# [9707]	validation_0-logloss:0.18462
# [9708]	validation_0-logloss:0.18462
# [9709]	validation_0-logloss:0.18462
# [9710]	validation_0-logloss:0.18461
# [9711]	validation_0-logloss:0.18460
# [9712]	validation_0-logloss:0.18460
# [9713]	validation_0-logloss:0.18458
# [9714]	validation_0-logloss:0.18456
# [9715]	validation_0-logloss:0.18457
# [9716]	validation_0-logloss:0.18457
# [9717]	validation_0-logloss:0.18454
# [9718]	validation_0-logloss:0.18454
# [9719]	validation_0-logloss:0.18454
# [9720]	validation_0-logloss:0.18454
# [9721]	validation_0-logloss:0.18454
# [9722]	validation_0-logloss:0.18453
# [9723]	validation_0-logloss:0.18453
# [9724]	validation_0-logloss:0.18452
# [9725]	validation_0-logloss:0.18452
# [9726]	validation_0-logloss:0.18452
# [9727]	validation_0-logloss:0.18451
# [9728]	validation_0-logloss:0.18451
# [9729]	validation_0-logloss:0.18451
# [9730]	validation_0-logloss:0.18451
# [9731]	validation_0-logloss:0.18451
# [9732]	validation_0-logloss:0.18451
# [9733]	validation_0-logloss:0.18450
# [9734]	validation_0-logloss:0.18449
# [9735]	validation_0-logloss:0.18448
# [9736]	validation_0-logloss:0.18448
# [9737]	validation_0-logloss:0.18447
# [9738]	validation_0-logloss:0.18446
# [9739]	validation_0-logloss:0.18444
# [9740]	validation_0-logloss:0.18444
# [9741]	validation_0-logloss:0.18444
# [9742]	validation_0-logloss:0.18444
# [9743]	validation_0-logloss:0.18444
# [9744]	validation_0-logloss:0.18443
# [9745]	validation_0-logloss:0.18443
# [9746]	validation_0-logloss:0.18443
# [9747]	validation_0-logloss:0.18443
# [9748]	validation_0-logloss:0.18441
# [9749]	validation_0-logloss:0.18441
# [9750]	validation_0-logloss:0.18440
# [9751]	validation_0-logloss:0.18440
# [9752]	validation_0-logloss:0.18440
# [9753]	validation_0-logloss:0.18439
# [9754]	validation_0-logloss:0.18439
# [9755]	validation_0-logloss:0.18439
# [9756]	validation_0-logloss:0.18438
# [9757]	validation_0-logloss:0.18438
# [9758]	validation_0-logloss:0.18436
# [9759]	validation_0-logloss:0.18436
# [9760]	validation_0-logloss:0.18435
# [9761]	validation_0-logloss:0.18434
# [9762]	validation_0-logloss:0.18434
# [9763]	validation_0-logloss:0.18433
# [9764]	validation_0-logloss:0.18433
# [9765]	validation_0-logloss:0.18434
# [9766]	validation_0-logloss:0.18433
# [9767]	validation_0-logloss:0.18434
# [9768]	validation_0-logloss:0.18432
# [9769]	validation_0-logloss:0.18432
# [9770]	validation_0-logloss:0.18432
# [9771]	validation_0-logloss:0.18432
# [9772]	validation_0-logloss:0.18432
# [9773]	validation_0-logloss:0.18430
# [9774]	validation_0-logloss:0.18429
# [9775]	validation_0-logloss:0.18429
# [9776]	validation_0-logloss:0.18428
# [9777]	validation_0-logloss:0.18428
# [9778]	validation_0-logloss:0.18427
# [9779]	validation_0-logloss:0.18426
# [9780]	validation_0-logloss:0.18426
# [9781]	validation_0-logloss:0.18426
# [9782]	validation_0-logloss:0.18425
# [9783]	validation_0-logloss:0.18425
# [9784]	validation_0-logloss:0.18424
# [9785]	validation_0-logloss:0.18423
# [9786]	validation_0-logloss:0.18423
# [9787]	validation_0-logloss:0.18423
# [9788]	validation_0-logloss:0.18423
# [9789]	validation_0-logloss:0.18422
# [9790]	validation_0-logloss:0.18420
# [9791]	validation_0-logloss:0.18420
# [9792]	validation_0-logloss:0.18421
# [9793]	validation_0-logloss:0.18420
# [9794]	validation_0-logloss:0.18419
# [9795]	validation_0-logloss:0.18418
# [9796]	validation_0-logloss:0.18419
# [9797]	validation_0-logloss:0.18419
# [9798]	validation_0-logloss:0.18417
# [9799]	validation_0-logloss:0.18416
# [9800]	validation_0-logloss:0.18414
# [9801]	validation_0-logloss:0.18413
# [9802]	validation_0-logloss:0.18412
# [9803]	validation_0-logloss:0.18412
# [9804]	validation_0-logloss:0.18411
# [9805]	validation_0-logloss:0.18409
# [9806]	validation_0-logloss:0.18409
# [9807]	validation_0-logloss:0.18408
# [9808]	validation_0-logloss:0.18407
# [9809]	validation_0-logloss:0.18407
# [9810]	validation_0-logloss:0.18405
# [9811]	validation_0-logloss:0.18404
# [9812]	validation_0-logloss:0.18404
# [9813]	validation_0-logloss:0.18403
# [9814]	validation_0-logloss:0.18402
# [9815]	validation_0-logloss:0.18401
# [9816]	validation_0-logloss:0.18401
# [9817]	validation_0-logloss:0.18400
# [9818]	validation_0-logloss:0.18399
# [9819]	validation_0-logloss:0.18398
# [9820]	validation_0-logloss:0.18397
# [9821]	validation_0-logloss:0.18397
# [9822]	validation_0-logloss:0.18397
# [9823]	validation_0-logloss:0.18396
# [9824]	validation_0-logloss:0.18396
# [9825]	validation_0-logloss:0.18394
# [9826]	validation_0-logloss:0.18395
# [9827]	validation_0-logloss:0.18394
# [9828]	validation_0-logloss:0.18393
# [9829]	validation_0-logloss:0.18392
# [9830]	validation_0-logloss:0.18392
# [9831]	validation_0-logloss:0.18391
# [9832]	validation_0-logloss:0.18391
# [9833]	validation_0-logloss:0.18390
# [9834]	validation_0-logloss:0.18391
# [9835]	validation_0-logloss:0.18390
# [9836]	validation_0-logloss:0.18390
# [9837]	validation_0-logloss:0.18390
# [9838]	validation_0-logloss:0.18389
# [9839]	validation_0-logloss:0.18389
# [9840]	validation_0-logloss:0.18388
# [9841]	validation_0-logloss:0.18388
# [9842]	validation_0-logloss:0.18387
# [9843]	validation_0-logloss:0.18387
# [9844]	validation_0-logloss:0.18387
# [9845]	validation_0-logloss:0.18386
# [9846]	validation_0-logloss:0.18385
# [9847]	validation_0-logloss:0.18385
# [9848]	validation_0-logloss:0.18385
# [9849]	validation_0-logloss:0.18384
# [9850]	validation_0-logloss:0.18384
# [9851]	validation_0-logloss:0.18383
# [9852]	validation_0-logloss:0.18383
# [9853]	validation_0-logloss:0.18384
# [9854]	validation_0-logloss:0.18383
# [9855]	validation_0-logloss:0.18383
# [9856]	validation_0-logloss:0.18382
# [9857]	validation_0-logloss:0.18382
# [9858]	validation_0-logloss:0.18382
# [9859]	validation_0-logloss:0.18380
# [9860]	validation_0-logloss:0.18380
# [9861]	validation_0-logloss:0.18380
# [9862]	validation_0-logloss:0.18379
# [9863]	validation_0-logloss:0.18378
# [9864]	validation_0-logloss:0.18378
# [9865]	validation_0-logloss:0.18376
# [9866]	validation_0-logloss:0.18375
# [9867]	validation_0-logloss:0.18375
# [9868]	validation_0-logloss:0.18375
# [9869]	validation_0-logloss:0.18373
# [9870]	validation_0-logloss:0.18372
# [9871]	validation_0-logloss:0.18372
# [9872]	validation_0-logloss:0.18371
# [9873]	validation_0-logloss:0.18371
# [9874]	validation_0-logloss:0.18372
# [9875]	validation_0-logloss:0.18372
# [9876]	validation_0-logloss:0.18372
# [9877]	validation_0-logloss:0.18370
# [9878]	validation_0-logloss:0.18369
# [9879]	validation_0-logloss:0.18369
# [9880]	validation_0-logloss:0.18369
# [9881]	validation_0-logloss:0.18369
# [9882]	validation_0-logloss:0.18368
# [9883]	validation_0-logloss:0.18367
# [9884]	validation_0-logloss:0.18366
# [9885]	validation_0-logloss:0.18366
# [9886]	validation_0-logloss:0.18365
# [9887]	validation_0-logloss:0.18364
# [9888]	validation_0-logloss:0.18363
# [9889]	validation_0-logloss:0.18363
# [9890]	validation_0-logloss:0.18362
# [9891]	validation_0-logloss:0.18361
# [9892]	validation_0-logloss:0.18360
# [9893]	validation_0-logloss:0.18360
# [9894]	validation_0-logloss:0.18360
# [9895]	validation_0-logloss:0.18359
# [9896]	validation_0-logloss:0.18358
# [9897]	validation_0-logloss:0.18359
# [9898]	validation_0-logloss:0.18357
# [9899]	validation_0-logloss:0.18358
# [9900]	validation_0-logloss:0.18356
# [9901]	validation_0-logloss:0.18356
# [9902]	validation_0-logloss:0.18355
# [9903]	validation_0-logloss:0.18356
# [9904]	validation_0-logloss:0.18356
# [9905]	validation_0-logloss:0.18355
# [9906]	validation_0-logloss:0.18355
# [9907]	validation_0-logloss:0.18355
# [9908]	validation_0-logloss:0.18355
# [9909]	validation_0-logloss:0.18355
# [9910]	validation_0-logloss:0.18356
# [9911]	validation_0-logloss:0.18355
# [9912]	validation_0-logloss:0.18354
# [9913]	validation_0-logloss:0.18353
# [9914]	validation_0-logloss:0.18353
# [9915]	validation_0-logloss:0.18353
# [9916]	validation_0-logloss:0.18351
# [9917]	validation_0-logloss:0.18351
# [9918]	validation_0-logloss:0.18351
# [9919]	validation_0-logloss:0.18350
# [9920]	validation_0-logloss:0.18349
# [9921]	validation_0-logloss:0.18348
# [9922]	validation_0-logloss:0.18349
# [9923]	validation_0-logloss:0.18349
# [9924]	validation_0-logloss:0.18348
# [9925]	validation_0-logloss:0.18348
# [9926]	validation_0-logloss:0.18348
# [9927]	validation_0-logloss:0.18348
# [9928]	validation_0-logloss:0.18348
# [9929]	validation_0-logloss:0.18347
# [9930]	validation_0-logloss:0.18347
# [9931]	validation_0-logloss:0.18346
# [9932]	validation_0-logloss:0.18346
# [9933]	validation_0-logloss:0.18346
# [9934]	validation_0-logloss:0.18344
# [9935]	validation_0-logloss:0.18344
# [9936]	validation_0-logloss:0.18344
# [9937]	validation_0-logloss:0.18344
# [9938]	validation_0-logloss:0.18344
# [9939]	validation_0-logloss:0.18343
# [9940]	validation_0-logloss:0.18343
# [9941]	validation_0-logloss:0.18343
# [9942]	validation_0-logloss:0.18343
# [9943]	validation_0-logloss:0.18343
# [9944]	validation_0-logloss:0.18343
# [9945]	validation_0-logloss:0.18342
# [9946]	validation_0-logloss:0.18341
# [9947]	validation_0-logloss:0.18341
# [9948]	validation_0-logloss:0.18340
# [9949]	validation_0-logloss:0.18340
# [9950]	validation_0-logloss:0.18339
# [9951]	validation_0-logloss:0.18339
# [9952]	validation_0-logloss:0.18337
# [9953]	validation_0-logloss:0.18336
# [9954]	validation_0-logloss:0.18336
# [9955]	validation_0-logloss:0.18336
# [9956]	validation_0-logloss:0.18336
# [9957]	validation_0-logloss:0.18335
# [9958]	validation_0-logloss:0.18335
# [9959]	validation_0-logloss:0.18334
# [9960]	validation_0-logloss:0.18333
# [9961]	validation_0-logloss:0.18332
# [9962]	validation_0-logloss:0.18332
# [9963]	validation_0-logloss:0.18331
# [9964]	validation_0-logloss:0.18330
# [9965]	validation_0-logloss:0.18330
# [9966]	validation_0-logloss:0.18330
# [9967]	validation_0-logloss:0.18330
# [9968]	validation_0-logloss:0.18330
# [9969]	validation_0-logloss:0.18328
# [9970]	validation_0-logloss:0.18328
# [9971]	validation_0-logloss:0.18327
# [9972]	validation_0-logloss:0.18326
# [9973]	validation_0-logloss:0.18325
# [9974]	validation_0-logloss:0.18325
# [9975]	validation_0-logloss:0.18325
# [9976]	validation_0-logloss:0.18323
# [9977]	validation_0-logloss:0.18322
# [9978]	validation_0-logloss:0.18322
# [9979]	validation_0-logloss:0.18320
# [9980]	validation_0-logloss:0.18320
# [9981]	validation_0-logloss:0.18318
# [9982]	validation_0-logloss:0.18318
# [9983]	validation_0-logloss:0.18318
# [9984]	validation_0-logloss:0.18317
# [9985]	validation_0-logloss:0.18316
# [9986]	validation_0-logloss:0.18316
# [9987]	validation_0-logloss:0.18316
# [9988]	validation_0-logloss:0.18314
# [9989]	validation_0-logloss:0.18314
# [9990]	validation_0-logloss:0.18312
# [9991]	validation_0-logloss:0.18312
# [9992]	validation_0-logloss:0.18310
# [9993]	validation_0-logloss:0.18311
# [9994]	validation_0-logloss:0.18311
# [9995]	validation_0-logloss:0.18311
# [9996]	validation_0-logloss:0.18310
# [9997]	validation_0-logloss:0.18310
# [9998]	validation_0-logloss:0.18309
# [9999]	validation_0-logloss:0.18309
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10000, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
# Make predictions
val_pred = xgb_model.predict(X_valid)
val_pred_proba = xgb_model.predict_proba(X_valid)[:,1]
test_pred_proba = xgb_model.predict_proba(X_test_processed)

# %%
# Create submission file
submission_file = pd.DataFrame()
submission_file['pk'] = test['pk']
submission_file['target'] = test_pred_proba[:,1]
submission_file.to_csv('submission.csv', index=False)

print("\nSubmission file created successfully!")
print("\nSubmission Preview:")
print(submission_file.head())
# Out:
# Submission file created successfully!
#
# Submission Preview:
#            pk    target
# 0  8831606085  0.073486
# 1  8831561565  0.009261
# 2  8831539811  0.901973
# 3  8831313791  0.566902
# 4  8831070109  0.048945

# %%
# Model Evaluation and Visualization
plt.style.use('seaborn-v0_8') # Using a valid seaborn style
sns.set_palette("husl")

# %%
# Create evaluation plots
plt.figure(figsize=(20, 15))
plt.subplot(2, 2, 1)
plt.plot(xgb_model.evals_result_['validation_0']['logloss'], label='Train')

# %%
# Confusion Matrix
plt.subplot(2, 2, 1)
cm = confusion_matrix(y_valid, val_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# ROC Curve
plt.subplot(2, 2, 2)
fpr, tpr, _ = roc_curve(y_valid, val_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")

# %%
# Precision-Recall Curve
plt.subplot(2, 2, 3)
precision, recall, _ = precision_recall_curve(y_valid, val_pred_proba)
plt.plot(recall, precision, color='blue', lw=2)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)

# %%
# Feature Importance
plt.subplot(2, 2, 4)
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': xgb_model.feature_importances_
})
feature_importance = feature_importance.sort_values('importance', ascending=False)
sns.barplot(x='importance', y='feature', data=feature_importance.head(10))
plt.title('Top 10 Feature Importance')

plt.tight_layout()
plt.show()

# %%
# Print model performance metrics
print("\nModel Performance Metrics:")
print("\nClassification Report:")
print(classification_report(y_valid, val_pred))
print(f"\nAccuracy Score: {accuracy_score(y_valid, val_pred):.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")

# Accessing the appropriate element of the precision array. Assuming you need the average precision.
# If a specific threshold's precision is required, change the index accordingly.
# Example:  precision[0] for the first threshold's precision.
print(f"Precision Score: {np.average(precision):.4f}")
print(f"Recall Score: {np.average(recall):.4f}")
# Out:
# Model Performance Metrics:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      5108
#            1       0.91      0.88      0.89      2247
#
#     accuracy                           0.94      7355
#    macro avg       0.93      0.92      0.92      7355
# weighted avg       0.94      0.94      0.94      7355
#
#
# Accuracy Score: 0.9361
# ROC AUC Score: 0.9741
# Precision Score: 0.6493
# Recall Score: 0.8293

# %%
# Prediction Distribution Analysis
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(val_pred_proba, bins=50)
plt.title('Validation Set Prediction Distribution')
plt.xlabel('Predicted Probability')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.histplot(test_pred_proba[:,1], bins=50)
plt.title('Test Set Prediction Distribution')
plt.xlabel('Predicted Probability')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Save analysis results
analysis_results = {
    'model_accuracy': accuracy_score(y_valid, val_pred),
    'roc_auc': roc_auc,
    'feature_importance': feature_importance.head(10).to_dict(),
    'confusion_matrix': cm.tolist()
}

with open('model_analysis_results.json', 'w') as f:
    json.dump(analysis_results, f)

print("\nAnalysis completed and results saved!")
print(f"Final Model Accuracy: {analysis_results['model_accuracy']:.4f}")
print(f"ROC AUC Score: {analysis_results['roc_auc']:.4f}")
# Out:
# Analysis completed and results saved!
# Final Model Accuracy: 0.9361
# ROC AUC Score: 0.9741
